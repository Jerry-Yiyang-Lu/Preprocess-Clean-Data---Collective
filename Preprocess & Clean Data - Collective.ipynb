# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#df = pd.read_excel('/content/gdrive/My Drive/Collective/All-Time Webinar Registrants.xlsx')

# %%
#display(df[0:10])

# %%
df_tax = pd.read_csv('/content/gdrive/My Drive/Collective/tax_calculator_entries_2022-01-28T23_04_26.012Z.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (11,12,13,18,26,27,29,55,56,57,58,59,60,65) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_tax.head(10)
# Out:
#        ID  ...                                         Tc All Ref
# 0  100089  ...                                         ?undefined
# 1  100088  ...  ?utm_adgroup=s_corp&placement=&device=m&utm_so...
# 2  100087  ...  ?utm_source=Collective&utm_medium=blog&utm_cam...
# 3  100086  ...  ?utm_source=tiktok&utm_medium=ads&utm_campaign...
# 4  100085  ...  ?utm_adgroup=&placement=&device=m&utm_source=g...
# 5  100084  ...  ?ad_id=23850008820660579&adset_id=238498680163...
# 6  100083  ...                                         ?undefined
# 7  100082  ...                                         ?undefined
# 8  100081  ...  ?utm_source=tiktok&utm_medium=ads&utm_campaign...
# 9  100080  ...  ?ad_id=23850009085030579&adset_id=238498671944...
#
# [10 rows x 67 columns]

# %%
date_list = []
for day in df_tax["Created"].str.split("T"):
  date_list.append(day[0])

# %%
df_tax["Date"]= date_list

# %%
df_tax["Date"].unique()
# Out:
# array(['2022-01-28', '2022-01-27', '2022-01-26', ..., '2018-11-22',
#        '2018-11-21', '2018-11-20'], dtype=object)

# %%
w=df_tax.Revenue.astype(float)
w[w<250]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-16f76bafa6ae> in <module>()
# ----> 1 w=df_tax.Revenue.astype(float)
#       2 w[w<250]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df_tax.drop(df_tax[df_tax['Revenue'] == "---"].index, inplace = True)

# %%
df_tax.drop(df_tax[df_tax['Revenue'] == "'"].index, inplace = True)

# %%
df_tax.drop(df_tax[df_tax['Revenue'] == 'nan'].index, inplace = True)

# %%
df_tax.drop(df_tax[df_tax['Revenue'] == 'string'].index, inplace = True)

# %%
list_ =[]
for index,row in df_tax.iterrows():
  try: float(row["Revenue"])
    
  except: list_.append(row["Revenue"])

# %%
set(list_)
# Out:
# {'$0',
#  '$00',
#  '$00,006',
#  '$000,000,000',
#  '$099,999',
#  '$1',
#  '$1,000',
#  '$1,000,000',
#  '$1,000,000,000',
#  '$1,050',
#  '$1,100,000',
#  '$1,120,000',
#  '$1,200',
#  '$1,200,000',
#  '$1,231,231',
#  '$1,241,841',
#  '$1,250',
#  '$1,250,000',
#  '$1,300,000',
#  '$1,332',
#  '$1,340',
#  '$1,341,050',
#  '$1,379',
#  '$1,389,163',
#  '$1,395,000',
#  '$1,400',
#  '$1,400,000',
#  '$1,500',
#  '$1,500,000',
#  '$1,570',
#  '$1,591',
#  '$1,600,000',
#  '$1,650,000',
#  '$1,681',
#  '$1,700,000',
#  '$1,701',
#  '$1,750,000',
#  '$1,800',
#  '$1,800,000',
#  '$1,924,000',
#  '$1,999,999',
#  '$10',
#  '$10,000',
#  '$10,000,000',
#  '$10,015',
#  '$10,201',
#  '$10,230',
#  '$10,332',
#  '$10,400',
#  '$10,500',
#  '$10,800',
#  '$10,923',
#  '$100',
#  '$100,000',
#  '$100,009',
#  '$100,010',
#  '$100,200',
#  '$100,250',
#  '$100,800',
#  '$101,000',
#  '$102,000',
#  '$102,222',
#  '$102,500',
#  '$102,600',
#  '$103,000',
#  '$103,100',
#  '$104,000',
# ...

# %%
df_tax["Revenue"]= df_tax["Revenue"].astype(str).str.replace("$", "").str.replace(",", "")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df_tax["Revenue"] = df_tax["Revenue"].astype(float)

# %%
set(df_tax["Revenue"])
# Out:
# {'114281',
#  '144000',
#  '462000',
#  '775000',
#  '65236',
#  '12399999',
#  '289000',
#  '21160',
#  '1498',
#  '314639',
#  '123456',
#  '500009',
#  '384160',
#  '31200',
#  '216988',
#  '181000',
#  '79989',
#  '440',
#  '0',
#  '119995',
#  '108000',
#  '2146',
#  '-5000',
#  '9800',
#  '88269',
#  '138000',
#  '44632',
#  '205000',
#  '152000',
#  '23000.00',
#  '90677',
#  '133333',
#  '33280',
#  '98860',
#  '5522215',
#  '324937',
#  '1231231',
#  '48000',
#  '34998',
#  '70500',
#  '-70000',
#  '111600',
#  '620000',
#  '100003',
#  '145500',
#  '222',
#  '-40000',
#  '199845',
#  '16000000000',
#  '48626',
#  '73000',
#  '3168',
#  '38862',
#  '22040',
#  '1900000',
#  '6000000',
#  '44400',
#  '179000',
#  '411208',
#  '93900',
#  '75675',
#  '251000',
#  '295000',
#  '29292',
#  '225650',
#  '2',
#  '10005',
#  '55600',
#  '69982',
#  '17500',
#  '251041',
#  '185000',
#  '53000',
#  '15984',
#  '6155840487',
#  '165600',
#  '640000',
#  '87600',
#  '100009',
# ...

# %%
set(df_tax["Tc State"])
# Out:
# {'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'Florida',
#  'Fujian',
#  'Georgia',
#  'Gujarat',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'Washington, D.C.',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming'}

# %%
df_tax["Revenue"]
# Out:
# 0         45000.0
# 1        225000.0
# 2         25000.0
# 3         40000.0
# 4         25000.0
#            ...
# 98523    100000.0
# 98525     45000.0
# 98526    150000.0
# 98527    250000.0
# 98529    250000.0
# Name: Revenue, Length: 85304, dtype: float64

# %%
df_tax.drop(df_tax[df_tax["Tc State"] == "---"].index, inplace = True)

# %%
df_tax.drop(df_tax[df_tax["Tc State"] == 'select one'].index, inplace = True)

# %%
df_tax.drop(df_tax[df_tax["Tc State"] == 'XSS'].index, inplace = True)

# %%
df_tax.drop(df_tax[df_tax["Tc State"] == '. '].index, inplace = True)

# %%
df_tax["Tc State"]= df_tax["Tc State"].str.replace("Texas ", "Texas")

# %%
df_tax["Tc State"]= df_tax["Tc State"].str.replace("+"," ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
df_tax["Tc State"]= df_tax["Tc State"].str.replace("california","California")

# %%
df_tax["Tc State"]= df_tax["Tc State"].str.replace("CA","California")

# %%
df_tax["Tc State"]= df_tax["Tc State"].str.replace("Illnois","Illinois")

# %%
set(df_tax["Tc Incorporation"])
# Out:
# {'LLC',
#  'MMLLC',
#  'SMLLC',
#  'SP',
#  'other',
#  'scorp',
#  'scorp-ccorp',
#  'scorp-mmllc',
#  'scorp-scorp',
#  'scorp-smllc'}

# %%
df_tax.drop(df_tax[df_tax["Tc Incorporation"] == '---'].index, inplace = True)

# %%
df_tax.drop(df_tax[df_tax["Tc Incorporation"] == 'Select entity type'].index, inplace = True)

# %%
#Check service
set(df_tax["Tc Services Type"])
# Out:
# {'---',
#  '50000',
#  'any-service-works',
#  'appraiser',
#  'coaching-consulting',
#  'design',
#  'home-inspector',
#  'other',
#  'real-estate-agent',
#  'sales-marketing-business-development',
#  'select your service',
#  'software-development',
#  'testing',
#  'videography'}

# %%
#Drop service =50000
df_tax.drop(df_tax[df_tax["Tc Services Type"]== '50000'].index, inplace = True)
set(df_tax["Tc Services Type"])
# Out:
# {'---',
#  'any-service-works',
#  'appraiser',
#  'coaching-consulting',
#  'design',
#  'home-inspector',
#  'other',
#  'real-estate-agent',
#  'sales-marketing-business-development',
#  'select your service',
#  'software-development',
#  'testing',
#  'videography'}

# %%
#df_tax[df_tax["Tc Services Type"] == 'select your service']

# %%
set(df_tax["Eligibility"])
# Out:
# {'---', 'pre-eligible', 'pre-noneligible'}

# %%
set(df_tax["Q Re Eligibility"])
# Out:
# {'---', 'pro-eligible', 'pro-noneligible'}

# %%
df_tax.head(2)
# Out:
#        ID  ...        Date
# 0  100089  ...  2022-01-28
# 1  100088  ...  2022-01-28
#
# [2 rows x 68 columns]

# %%
#set(df_tax[df_tax["Eligibility"]=="pre-eligible"][df_tax["Q Re Eligibility"] == "pro-eligible" ]["Revenue"])

# %%
# Clean email 
df_tax.drop(df_tax[df_tax["Tc Email"]=="%@hyke%"].index, inplace = True)
df_tax.drop(df_tax[df_tax["Tc Email"]=="jacobfrediani@gmail.com"].index, inplace = True)
df_tax.drop(df_tax[df_tax["Tc Email"]=="elon@tesla.com"].index, inplace = True)
df_tax.drop(df_tax[df_tax["Tc Email"]=="elon@gmail.com"].index, inplace = True)
df_tax.drop(df_tax[df_tax["Tc Email"]=="rezenbiz@gmail.com"].index, inplace = True)
df_tax.drop(df_tax[df_tax["Tc Email"]=="elon@elon.com"].index, inplace = True)
df_tax.drop(df_tax[df_tax["Tc Email"]=='---' ].index, inplace = True)
df_tax.drop(df_tax[df_tax['Tc Email'].str.contains("@collective.com")].index, inplace = True)
df_tax.drop(df_tax[df_tax['Tc Email'].str.contains("@test.com")].index, inplace = True)
#df_tax[df_tax['Tc Email'].str.contains("@")==0]

# %%
df_tax.head(2)
# Out:
#        ID  ...        Date
# 0  100089  ...  2022-01-28
# 1  100088  ...  2022-01-28
#
# [2 rows x 68 columns]

# %%
set(df_tax["Utm Source"])
# Out:
# {'---',
#  'Ashley_Hogrebe',
#  'BDR',
#  'BetterWallet',
#  'Bunker',
#  'CURRENT MEMBERS',
#  'Ceci Marshall',
#  'Collective',
#  'Create and Cultivate',
#  'Danekia',
#  'Delyanne',
#  'Duke',
#  'Dustin-Talley',
#  'Facebook',
#  'FinConAffiliates',
#  'FreelancingFemales',
#  'Google',
#  'GrowthCollective',
#  'Gusto',
#  'Instagram',
#  'Jessica Blankenship',
#  'Josh-Curtis',
#  'Kesha-JonTae',
#  'Lindsay-Thomson',
#  'LinkedIn',
#  'Lumanu',
#  'Mane-Influencer',
#  'Marketerhire',
#  'Millo Newsletter',
#  'Morgan-Overholt',
#  'NAWBO',
#  'Nathalia-Ramos',
#  'Nikki Venus',
#  'Oanh Nhi',
#  'PEA',
#  'Patreon',
#  'Paul Fisherman',
#  'RaisinBread',
#  'SEM',
#  'Tasha-Jones',
#  'Tiffani-Purdy',
#  'TikTok',
#  'Twine Users',
#  'Tyrone-Marshall-Jr',
#  'Vanader',
#  'Wethos',
#  "['Collective', 'Collective']",
#  "['Marketerhire', 'hs_automation']",
#  'adwords',
#  'hs_automation',
#  'hs_email'}

# %%
df_tax["Utm Source"]= df_tax["Utm Source"].str.replace("Create-and-Cultivate","Create and Cultivate")

# %%
df_tax["Utm Source"]= df_tax["Utm Source"].str.replace("collective","Collective")

# %%
df_tax["Utm Source"]= df_tax["Utm Source"].str.replace("tiktok","TikTok")

# %%
df_tax["Utm Source"]= df_tax["Utm Source"].str.replace("facebook","Facebook")

# %%
df_tax["Utm Source"]= df_tax["Utm Source"].str.replace("google","Google")

# %%
df_tax["Utm Source"]= df_tax["Utm Source"].str.replace("Mane","Mane-Influencer")

# %%
df_tax["Utm Source"]= df_tax["Utm Source"].str.replace("Mane-Influencer-Influencer","Mane-Influencer")

# %%
df_tax["Date"]=pd.to_datetime(df_tax['Date'])

# %%
df = df_tax.loc[:,["ID","Date","Tc Email","Eligibility","Q Re Eligibility","Revenue","Tc State","Tc Incorporation","Tc Services Type",\
              "Tc Pro License","Tc Resident","Tc Same State","Tc Tangible Goods","Tc Financial Assets","Tc Assets Over Worth","Utm Source"]]
df=df.reset_index(drop=True)
df
# Out:
#            ID       Date  ... Tc Assets Over Worth  Utm Source
# 0      100089 2022-01-28  ...                  NaN         ---
# 1      100088 2022-01-28  ...                  NaN      Google
# 2      100087 2022-01-28  ...                  NaN  Collective
# 3      100086 2022-01-28  ...                  NaN      TikTok
# 4      100085 2022-01-28  ...                  NaN      Google
# ...       ...        ...  ...                  ...         ...
# 55185     107 2018-11-27  ...                  ---         ---
# 55186      78 2018-11-23  ...                  ---         ---
# 55187      76 2018-11-22  ...                  ---         ---
# 55188      73 2018-11-22  ...                  ---         ---
# 55189      63 2018-11-20  ...                  ---         ---
#
# [55190 rows x 16 columns]

# %%
df.to_excel("/content/gdrive/My Drive/Collective/collective_2_27_2022.xlsx")
